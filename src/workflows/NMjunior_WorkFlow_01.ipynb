# %% [markdown]
# # 7 WorkFlow

# %% [markdown]
# ### 7.1 Objetivo

# %% [markdown]
# Presentar un workflow/pipeline completo al que los estudiantes deberán enriquecer

# %% [markdown]
# #### 7.2  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab
# *   Bajar el **dataset_historico** al Google Drive y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %% [markdown]
# *  Si usted eligió modalidad *Gerencial* entonces NO debe modificar nada, su liderazgo logró que otras trabajaron por usted
# *  Si usted eligió modalidad de *Analista Junior*, entonces donde dice archivo="gerencial_competencia_2025.csv.gz"  lo debe cambiar por  archivo="analistajr_competencia_2025.csv.gz"
# *  Si usted eligió modalidad *Analista Senior*,  ya se las ingenierá SIN preguntar !

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets


webfiles="https://storage.googleapis.com/open-courses/austral2025-af91/labo1r"
destino_local="/content/datasets"
destino_bucket="/content/buckets/b1/datasets"


archivo="dataset_pequeno.csv"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

#-------

archivo="analistajr_competencia_2025.csv.gz"

if ! test -f $destino_bucket/$archivo; then
  wget  $webfiles/$archivo  -O $destino_bucket/$archivo
fi


if ! test -f $destino_local/$pequeno; then
  cp  $destino_bucket/$archivo  $destino_local/$archivo
fi

# %% [markdown]
# ## 7.3  Workflow

# %% [markdown]
# ## Inicializacion

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Fri Jun 27 23:46:33 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  653531 35.0 1439345    76.9 1383156  73.9
# Vcells 1218126  9.3 8388608    64.0 1924955  14.7

# %%
require("data.table")

if( !require("R.utils")) install.packages("R.utils")
require("R.utils")
# Out:
# Loading required package: data.table
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings

# %% [markdown]
# #### Parametros
# Si es gerente, no cambie nada
# <br>Si es Analista, cambie el nombre del dataset

# %%
PARAM <- list()
PARAM$semilla_primigenia <- 532993 

PARAM$experimento <- 7300
PARAM$dataset <- "analistajr_competencia_2025.csv.gz"

# %% [markdown]
# #### Carpeta del Experimento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("WF", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %% [markdown]
# ### 7.3.1   Preprocesamiento del dataset

# %% [markdown]
# #### 7.3.1.1  DT incorporar dataset

# %%
# lectura del dataset
dataset <- fread(paste0("/content/datasets/", PARAM$dataset))

# %% [markdown]
# #### 7.3.1.2  CA  Catastrophe Analysis
# Se intentan reparar las variables que para un mes están con todos los valores en cero.

# %% [markdown]
# El método que se utiliza es **Machine Learning** se asigna NA also valores, si ha leido bien, es la "anti imputación de valores faltantes"
# <br> Usted podrá aplicar aquí otros métodos

# %%
dataset[ foto_mes==202006, internet:=NA]
dataset[ foto_mes==202006, mrentabilidad:=NA]
dataset[ foto_mes==202006, mrentabilidad_annual:=NA]
dataset[ foto_mes==202006, mcomisiones:=NA]
dataset[ foto_mes==202006, mactivos_margen:=NA]
dataset[ foto_mes==202006, mpasivos_margen:=NA]
dataset[ foto_mes==202006, mcuentas_saldo:=NA]
dataset[ foto_mes==202006, ctarjeta_visa_transacciones:=NA]
dataset[ foto_mes==202006, mtarjeta_visa_consumo:=NA]
dataset[ foto_mes==202006, mtarjeta_master_consumo:=NA]
dataset[ foto_mes==202006, ccallcenter_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]
dataset[ foto_mes==202006, chomebanking_transacciones:=NA]

# %% [markdown]
# #### 7.3.1.3  DR  Data Drifting
# Se intenta corregir el data drifting, quizas ajustando por IPC ...
# <br>Esta parte podrá ser abordada por todos los Analistas y también la Gerenciapero se decide pedagogicamente no incluirla en esta primer version para reducir la carga cognitiva

# %%
# sin codigo en esta primera version del workflow

# %% [markdown]
# #### 7.3.1.3  FE_intra_manual Feature Engineering intra-mes
#
# Agrego campos nuevos dentro del mismo mes, SIN considerar la historia.

# %%
# esta funcion atributos presentes existe debido a que las modalidades poseen datasets con distinta cantidad de campos
atributos_presentes <- function( patributos )
{
  atributos <- unique( patributos )
  comun <- intersect( atributos, colnames(dataset) )

  return(  length( atributos ) == length( comun ) )
}

# el mes 1,2, ..12
if( atributos_presentes( c("foto_mes") ))
  dataset[, kmes := foto_mes %% 100]

# variable extraida de una tesis de maestria de Irlanda
if( atributos_presentes( c("mpayroll", "cliente_edad") ))
  dataset[, mpayroll_sobre_edad := mpayroll / cliente_edad]

# %%
# visualizo las columas del dataset a esta etapa
colnames(dataset)
# Out:
#  [1] "numero_de_cliente"                  "foto_mes"
#  [3] "internet"                           "cliente_edad"
#  [5] "cliente_antiguedad"                 "mrentabilidad"
#  [7] "mrentabilidad_annual"               "mcomisiones"
#  [9] "mactivos_margen"                    "mpasivos_margen"
# [11] "cproductos"                         "mcuenta_corriente"
# [13] "mcaja_ahorro"                       "cdescubierto_preacordado"
# [15] "mcuentas_saldo"                     "ctarjeta_visa"
# [17] "ctarjeta_visa_transacciones"        "mtarjeta_visa_consumo"
# [19] "ctarjeta_master"                    "ctarjeta_master_transacciones"
# [21] "mtarjeta_master_consumo"            "cprestamos_personales"
# [23] "mprestamos_personales"              "cpayroll_trx"
# [25] "mpayroll"                           "mttarjeta_visa_debitos_automaticos"
# [27] "ccomisiones_mantenimiento"          "mcomisiones_mantenimiento"
# [29] "ccomisiones_otras"                  "mtransferencias_recibidas"
# [31] "ccallcenter_transacciones"          "thomebanking"
# [33] "chomebanking_transacciones"         "ctrx_quarter"
# [35] "Master_status"                      "Master_mfinanciacion_limite"
# [37] "Master_Fvencimiento"                "Master_msaldototal"
# [39] "Master_mlimitecompra"               "Master_fultimo_cierre"
# [41] "Master_fechaalta"                   "Master_mconsumototal"
# [43] "Master_cconsumos"                   "Master_mpagominimo"
# [45] "Visa_status"                        "Visa_mfinanciacion_limite"
# [47] "Visa_Fvencimiento"                  "Visa_msaldototal"
# [49] "Visa_mlimitecompra"                 "Visa_fultimo_cierre"
# [51] "Visa_fechaalta"                     "Visa_mconsumototal"
# [53] "Visa_cconsumos"                     "Visa_mpagominimo"
# [55] "clase_ternaria"                     "kmes"
# [57] "mpayroll_sobre_edad"

# %% [markdown]
# #### 7.3.1.4  FE_rf Feature Engineering de nuevas variables a partir de hojas de Random Forest
#
# Esto se mostrará unicamente a la *modalidad Analista Sr*

# %%
# No se implementa Feature Engineering a partir de Random Forest

# %% [markdown]
# #### 7.3.1.5  FEhist Feature Engineering historico
#
# El Fature Engineering Histórico es la etapa que más aporta a la ganancia final, ya que enriquece cada registro del dataset con su historia.

# %% [markdown]
# Para cada campo del dataset original (*)
# se crean lo siguientes campos de a partir de la historia
# * lag1  lags de orden 1
# * delta1  =  valor actual - lag1
# * lag2  lags de orden 2
# * delta2  = valor actual - lag2
#
#
# (*) Excepto para los campos  <numero_de_cliente,  foto_mes,  clase_ternaria>

# %%
# Feature Engineering Historico

# todo es lagueable, menos la primary key y la clase
cols_lagueables <- copy( setdiff(
    colnames(dataset),
    c("numero_de_cliente", "foto_mes", "clase_ternaria")
) )

# https://rdrr.io/cran/data.table/man/shift.html

# lags de orden 1
dataset[,
    paste0(cols_lagueables, "_lag1") := shift(.SD, 1, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# lags de orden 2
dataset[,
    paste0(cols_lagueables, "_lag2") := shift(.SD, 2, NA, "lag"),
    by = numero_de_cliente,
    .SDcols = cols_lagueables
]

# agrego los delta lags
for (vcol in cols_lagueables)
{
    dataset[, paste0(vcol, "_delta1") := get(vcol) - get(paste0(vcol, "_lag1"))]
    dataset[, paste0(vcol, "_delta2") := get(vcol) - get(paste0(vcol, "_lag2"))]
}

# %% [markdown]
# Verificacion de los campos recien creados

# %%
ncol(dataset)
colnames(dataset)
# Out:
# [1] 1137
#    [1] "numero_de_cliente"
#    [2] "foto_mes"
#    [3] "internet"
#    [4] "cliente_edad"
#    [5] "cliente_antiguedad"
#    [6] "mrentabilidad"
#    [7] "mrentabilidad_annual"
#    [8] "mcomisiones"
#    [9] "mactivos_margen"
#   [10] "mpasivos_margen"
#   [11] "cproductos"
#   [12] "mcuenta_corriente"
#   [13] "mcaja_ahorro"
#   [14] "cdescubierto_preacordado"
#   [15] "mcuentas_saldo"
#   [16] "ctarjeta_visa"
#   [17] "ctarjeta_visa_transacciones"
#   [18] "mtarjeta_visa_consumo"
#   [19] "ctarjeta_master"
#   [20] "ctarjeta_master_transacciones"
#   [21] "mtarjeta_master_consumo"
#   [22] "cprestamos_personales"
#   [23] "mprestamos_personales"
#   [24] "cpayroll_trx"
#   [25] "mpayroll"
#   [26] "mttarjeta_visa_debitos_automaticos"
#   [27] "ccomisiones_mantenimiento"
#   [28] "mcomisiones_mantenimiento"
#   [29] "ccomisiones_otras"
#   [30] "mtransferencias_recibidas"
#   [31] "ccallcenter_transacciones"
#   [32] "thomebanking"
#   [33] "chomebanking_transacciones"
#   [34] "ctrx_quarter"
#   [35] "Master_status"
#   [36] "Master_mfinanciacion_limite"
#   [37] "Master_Fvencimiento"
#   [38] "Master_msaldototal"
#   [39] "Master_mlimitecompra"
#   [40] "Master_fultimo_cierre"
#   [41] "Master_fechaalta"
#   [42] "Master_mconsumototal"
#   [43] "Master_cconsumos"
#   [44] "Master_mpagominimo"
#   [45] "Visa_status"
#   [46] "Visa_mfinanciacion_limite"
#   [47] "Visa_Fvencimiento"
#   [48] "Visa_msaldototal"
#   [49] "Visa_mlimitecompra"
#   [50] "Visa_fultimo_cierre"
#   [51] "Visa_fechaalta"
#   [52] "Visa_mconsumototal"
#   [53] "Visa_cconsumos"
#   [54] "Visa_mpagominimo"
#   [55] "clase_ternaria"
#   [56] "kmes"
#   [57] "mpayroll_sobre_edad"
#   [58] "internet_lag1"
#   [59] "cliente_edad_lag1"
#   [60] "cliente_antiguedad_lag1"
#   [61] "mrentabilidad_lag1"
#   [62] "mrentabilidad_annual_lag1"
#   [63] "mcomisiones_lag1"
#   [64] "mactivos_margen_lag1"
#   [65] "mpasivos_margen_lag1"
#   [66] "cproductos_lag1"
#   [67] "mcuenta_corriente_lag1"
#   [68] "mcaja_ahorro_lag1"
#   [69] "cdescubierto_preacordado_lag1"
#   [70] "mcuentas_saldo_lag1"
#   [71] "ctarjeta_visa_lag1"
#   [72] "ctarjeta_visa_transacciones_lag1"
#   [73] "mtarjeta_visa_consumo_lag1"
#   [74] "ctarjeta_master_lag1"
#   [75] "ctarjeta_master_transacciones_lag1"
#   [76] "mtarjeta_master_consumo_lag1"
#   [77] "cprestamos_personales_lag1"
#   [78] "mprestamos_personales_lag1"
#   [79] "cpayroll_trx_lag1"
#   [80] "mpayroll_lag1"
#   [81] "mttarjeta_visa_debitos_automaticos_lag1"
#   [82] "ccomisiones_mantenimiento_lag1"
#   [83] "mcomisiones_mantenimiento_lag1"
#   [84] "ccomisiones_otras_lag1"
#   [85] "mtransferencias_recibidas_lag1"
#   [86] "ccallcenter_transacciones_lag1"
#   [87] "thomebanking_lag1"
#   [88] "chomebanking_transacciones_lag1"
#   [89] "ctrx_quarter_lag1"
#   [90] "Master_status_lag1"
#   [91] "Master_mfinanciacion_limite_lag1"
#   [92] "Master_Fvencimiento_lag1"
#   [93] "Master_msaldototal_lag1"
#   [94] "Master_mlimitecompra_lag1"
#   [95] "Master_fultimo_cierre_lag1"
#   [96] "Master_fechaalta_lag1"
#   [97] "Master_mconsumototal_lag1"
#   [98] "Master_cconsumos_lag1"
#   [99] "Master_mpagominimo_lag1"
#  [100] "Visa_status_lag1"
#  [101] "Visa_mfinanciacion_limite_lag1"
#  [102] "Visa_Fvencimiento_lag1"
#  [103] "Visa_msaldototal_lag1"
#  [104] "Visa_mlimitecompra_lag1"
#  [105] "Visa_fultimo_cierre_lag1"
#  [106] "Visa_fechaalta_lag1"
#  [107] "Visa_mconsumototal_lag1"
#  [108] "Visa_cconsumos_lag1"
#  [109] "Visa_mpagominimo_lag1"
#  [110] "kmes_lag1"
#  [111] "mpayroll_sobre_edad_lag1"
#  [112] "internet_lag2"
#  [113] "cliente_edad_lag2"
#  [114] "cliente_antiguedad_lag2"
#  [115] "mrentabilidad_lag2"
#  [116] "mrentabilidad_annual_lag2"
#  [117] "mcomisiones_lag2"
#  [118] "mactivos_margen_lag2"
#  [119] "mpasivos_margen_lag2"
#  [120] "cproductos_lag2"
#  [121] "mcuenta_corriente_lag2"
#  [122] "mcaja_ahorro_lag2"
#  [123] "cdescubierto_preacordado_lag2"
#  [124] "mcuentas_saldo_lag2"
#  [125] "ctarjeta_visa_lag2"
#  [126] "ctarjeta_visa_transacciones_lag2"
#  [127] "mtarjeta_visa_consumo_lag2"
#  [128] "ctarjeta_master_lag2"
#  [129] "ctarjeta_master_transacciones_lag2"
#  [130] "mtarjeta_master_consumo_lag2"
#  [131] "cprestamos_personales_lag2"
#  [132] "mprestamos_personales_lag2"
#  [133] "cpayroll_trx_lag2"
#  [134] "mpayroll_lag2"
#  [135] "mttarjeta_visa_debitos_automaticos_lag2"
#  [136] "ccomisiones_mantenimiento_lag2"
#  [137] "mcomisiones_mantenimiento_lag2"
#  [138] "ccomisiones_otras_lag2"
#  [139] "mtransferencias_recibidas_lag2"
#  [140] "ccallcenter_transacciones_lag2"
#  [141] "thomebanking_lag2"
#  [142] "chomebanking_transacciones_lag2"
#  [143] "ctrx_quarter_lag2"
#  [144] "Master_status_lag2"
#  [145] "Master_mfinanciacion_limite_lag2"
#  [146] "Master_Fvencimiento_lag2"
#  [147] "Master_msaldototal_lag2"
#  [148] "Master_mlimitecompra_lag2"
#  [149] "Master_fultimo_cierre_lag2"
#  [150] "Master_fechaalta_lag2"
#  [151] "Master_mconsumototal_lag2"
#  [152] "Master_cconsumos_lag2"
#  [153] "Master_mpagominimo_lag2"
#  [154] "Visa_status_lag2"
#  [155] "Visa_mfinanciacion_limite_lag2"
#  [156] "Visa_Fvencimiento_lag2"
#  [157] "Visa_msaldototal_lag2"
#  [158] "Visa_mlimitecompra_lag2"
#  [159] "Visa_fultimo_cierre_lag2"
#  [160] "Visa_fechaalta_lag2"
#  [161] "Visa_mconsumototal_lag2"
#  [162] "Visa_cconsumos_lag2"
#  [163] "Visa_mpagominimo_lag2"
#  [164] "kmes_lag2"
#  [165] "mpayroll_sobre_edad_lag2"
#  [166] "internet_delta1"
#  [167] "internet_delta2"
#  [168] "cliente_edad_delta1"
#  [169] "cliente_edad_delta2"
#  [170] "cliente_antiguedad_delta1"
#  [171] "cliente_antiguedad_delta2"
#  [172] "mrentabilidad_delta1"
#  [173] "mrentabilidad_delta2"
#  [174] "mrentabilidad_annual_delta1"
#  [175] "mrentabilidad_annual_delta2"
#  [176] "mcomisiones_delta1"
#  [177] "mcomisiones_delta2"
#  [178] "mactivos_margen_delta1"
#  [179] "mactivos_margen_delta2"
#  [180] "mpasivos_margen_delta1"
#  [181] "mpasivos_margen_delta2"
#  [182] "cproductos_delta1"
#  [183] "cproductos_delta2"
#  [184] "mcuenta_corriente_delta1"
#  [185] "mcuenta_corriente_delta2"
#  [186] "mcaja_ahorro_delta1"
#  [187] "mcaja_ahorro_delta2"
#  [188] "cdescubierto_preacordado_delta1"
#  [189] "cdescubierto_preacordado_delta2"
#  [190] "mcuentas_saldo_delta1"
#  [191] "mcuentas_saldo_delta2"
#  [192] "ctarjeta_visa_delta1"
#  [193] "ctarjeta_visa_delta2"
#  [194] "ctarjeta_visa_transacciones_delta1"
#  [195] "ctarjeta_visa_transacciones_delta2"
#  [196] "mtarjeta_visa_consumo_delta1"
#  [197] "mtarjeta_visa_consumo_delta2"
#  [198] "ctarjeta_master_delta1"
#  [199] "ctarjeta_master_delta2"
#  [200] "ctarjeta_master_transacciones_delta1"
#  [201] "ctarjeta_master_transacciones_delta2"
#  [202] "mtarjeta_master_consumo_delta1"
#  [203] "mtarjeta_master_consumo_delta2"
#  [204] "cprestamos_personales_delta1"
#  [205] "cprestamos_personales_delta2"
#  [206] "mprestamos_personales_delta1"
#  [207] "mprestamos_personales_delta2"
#  [208] "cpayroll_trx_delta1"
#  [209] "cpayroll_trx_delta2"
#  [210] "mpayroll_delta1"
#  [211] "mpayroll_delta2"
#  [212] "mttarjeta_visa_debitos_automaticos_delta1"
#  [213] "mttarjeta_visa_debitos_automaticos_delta2"
#  [214] "ccomisiones_mantenimiento_delta1"
#  [215] "ccomisiones_mantenimiento_delta2"
#  [216] "mcomisiones_mantenimiento_delta1"
#  [217] "mcomisiones_mantenimiento_delta2"
#  [218] "ccomisiones_otras_delta1"
#  [219] "ccomisiones_otras_delta2"
#  [220] "mtransferencias_recibidas_delta1"
#  [221] "mtransferencias_recibidas_delta2"
#  [222] "ccallcenter_transacciones_delta1"
#  [223] "ccallcenter_transacciones_delta2"
#  [224] "thomebanking_delta1"
#  [225] "thomebanking_delta2"
#  [226] "chomebanking_transacciones_delta1"
#  [227] "chomebanking_transacciones_delta2"
#  [228] "ctrx_quarter_delta1"
#  [229] "ctrx_quarter_delta2"
#  [230] "Master_status_delta1"
#  [231] "Master_status_delta2"
#  [232] "Master_mfinanciacion_limite_delta1"
#  [233] "Master_mfinanciacion_limite_delta2"
#  [234] "Master_Fvencimiento_delta1"
#  [235] "Master_Fvencimiento_delta2"
#  [236] "Master_msaldototal_delta1"
#  [237] "Master_msaldototal_delta2"
#  [238] "Master_mlimitecompra_delta1"
#  [239] "Master_mlimitecompra_delta2"
#  [240] "Master_fultimo_cierre_delta1"
#  [241] "Master_fultimo_cierre_delta2"
#  [242] "Master_fechaalta_delta1"
#  [243] "Master_fechaalta_delta2"
#  [244] "Master_mconsumototal_delta1"
#  [245] "Master_mconsumototal_delta2"
#  [246] "Master_cconsumos_delta1"
#  [247] "Master_cconsumos_delta2"
#  [248] "Master_mpagominimo_delta1"
#  [249] "Master_mpagominimo_delta2"
#  [250] "Visa_status_delta1"
#  [251] "Visa_status_delta2"
#  [252] "Visa_mfinanciacion_limite_delta1"
#  [253] "Visa_mfinanciacion_limite_delta2"
#  [254] "Visa_Fvencimiento_delta1"
#  [255] "Visa_Fvencimiento_delta2"
#  [256] "Visa_msaldototal_delta1"
#  [257] "Visa_msaldototal_delta2"
#  [258] "Visa_mlimitecompra_delta1"
#  [259] "Visa_mlimitecompra_delta2"
#  [260] "Visa_fultimo_cierre_delta1"
#  [261] "Visa_fultimo_cierre_delta2"
#  [262] "Visa_fechaalta_delta1"
#  [263] "Visa_fechaalta_delta2"
#  [264] "Visa_mconsumototal_delta1"
#  [265] "Visa_mconsumototal_delta2"
#  [266] "Visa_cconsumos_delta1"
#  [267] "Visa_cconsumos_delta2"
#  [268] "Visa_mpagominimo_delta1"
#  [269] "Visa_mpagominimo_delta2"
#  [270] "kmes_delta1"
#  [271] "kmes_delta2"
#  [272] "mpayroll_sobre_edad_delta1"
#  [273] "mpayroll_sobre_edad_delta2"
#  [274] "internet_lag1_lag1"
#  [275] "cliente_edad_lag1_lag1"
#  [276] "cliente_antiguedad_lag1_lag1"
#  [277] "mrentabilidad_lag1_lag1"
#  [278] "mrentabilidad_annual_lag1_lag1"
#  [279] "mcomisiones_lag1_lag1"
#  [280] "mactivos_margen_lag1_lag1"
#  [281] "mpasivos_margen_lag1_lag1"
#  [282] "cproductos_lag1_lag1"
#  [283] "mcuenta_corriente_lag1_lag1"
#  [284] "mcaja_ahorro_lag1_lag1"
#  [285] "cdescubierto_preacordado_lag1_lag1"
#  [286] "mcuentas_saldo_lag1_lag1"
#  [287] "ctarjeta_visa_lag1_lag1"
#  [288] "ctarjeta_visa_transacciones_lag1_lag1"
#  [289] "mtarjeta_visa_consumo_lag1_lag1"
#  [290] "ctarjeta_master_lag1_lag1"
#  [291] "ctarjeta_master_transacciones_lag1_lag1"
#  [292] "mtarjeta_master_consumo_lag1_lag1"
#  [293] "cprestamos_personales_lag1_lag1"
#  [294] "mprestamos_personales_lag1_lag1"
#  [295] "cpayroll_trx_lag1_lag1"
#  [296] "mpayroll_lag1_lag1"
#  [297] "mttarjeta_visa_debitos_automaticos_lag1_lag1"
#  [298] "ccomisiones_mantenimiento_lag1_lag1"
#  [299] "mcomisiones_mantenimiento_lag1_lag1"
#  [300] "ccomisiones_otras_lag1_lag1"
#  [301] "mtransferencias_recibidas_lag1_lag1"
#  [302] "ccallcenter_transacciones_lag1_lag1"
#  [303] "thomebanking_lag1_lag1"
#  [304] "chomebanking_transacciones_lag1_lag1"
#  [305] "ctrx_quarter_lag1_lag1"
#  [306] "Master_status_lag1_lag1"
#  [307] "Master_mfinanciacion_limite_lag1_lag1"
#  [308] "Master_Fvencimiento_lag1_lag1"
#  [309] "Master_msaldototal_lag1_lag1"
#  [310] "Master_mlimitecompra_lag1_lag1"
#  [311] "Master_fultimo_cierre_lag1_lag1"
#  [312] "Master_fechaalta_lag1_lag1"
#  [313] "Master_mconsumototal_lag1_lag1"
#  [314] "Master_cconsumos_lag1_lag1"
#  [315] "Master_mpagominimo_lag1_lag1"
#  [316] "Visa_status_lag1_lag1"
#  [317] "Visa_mfinanciacion_limite_lag1_lag1"
#  [318] "Visa_Fvencimiento_lag1_lag1"
#  [319] "Visa_msaldototal_lag1_lag1"
#  [320] "Visa_mlimitecompra_lag1_lag1"
#  [321] "Visa_fultimo_cierre_lag1_lag1"
#  [322] "Visa_fechaalta_lag1_lag1"
#  [323] "Visa_mconsumototal_lag1_lag1"
#  [324] "Visa_cconsumos_lag1_lag1"
#  [325] "Visa_mpagominimo_lag1_lag1"
#  [326] "kmes_lag1_lag1"
#  [327] "mpayroll_sobre_edad_lag1_lag1"
#  [328] "internet_lag2_lag1"
#  [329] "cliente_edad_lag2_lag1"
#  [330] "cliente_antiguedad_lag2_lag1"
#  [331] "mrentabilidad_lag2_lag1"
#  [332] "mrentabilidad_annual_lag2_lag1"
#  [333] "mcomisiones_lag2_lag1"
#  [334] "mactivos_margen_lag2_lag1"
#  [335] "mpasivos_margen_lag2_lag1"
#  [336] "cproductos_lag2_lag1"
#  [337] "mcuenta_corriente_lag2_lag1"
#  [338] "mcaja_ahorro_lag2_lag1"
#  [339] "cdescubierto_preacordado_lag2_lag1"
#  [340] "mcuentas_saldo_lag2_lag1"
#  [341] "ctarjeta_visa_lag2_lag1"
#  [342] "ctarjeta_visa_transacciones_lag2_lag1"
#  [343] "mtarjeta_visa_consumo_lag2_lag1"
#  [344] "ctarjeta_master_lag2_lag1"
#  [345] "ctarjeta_master_transacciones_lag2_lag1"
#  [346] "mtarjeta_master_consumo_lag2_lag1"
#  [347] "cprestamos_personales_lag2_lag1"
#  [348] "mprestamos_personales_lag2_lag1"
#  [349] "cpayroll_trx_lag2_lag1"
#  [350] "mpayroll_lag2_lag1"
#  [351] "mttarjeta_visa_debitos_automaticos_lag2_lag1"
#  [352] "ccomisiones_mantenimiento_lag2_lag1"
#  [353] "mcomisiones_mantenimiento_lag2_lag1"
#  [354] "ccomisiones_otras_lag2_lag1"
#  [355] "mtransferencias_recibidas_lag2_lag1"
#  [356] "ccallcenter_transacciones_lag2_lag1"
#  [357] "thomebanking_lag2_lag1"
#  [358] "chomebanking_transacciones_lag2_lag1"
#  [359] "ctrx_quarter_lag2_lag1"
#  [360] "Master_status_lag2_lag1"
#  [361] "Master_mfinanciacion_limite_lag2_lag1"
#  [362] "Master_Fvencimiento_lag2_lag1"
#  [363] "Master_msaldototal_lag2_lag1"
#  [364] "Master_mlimitecompra_lag2_lag1"
#  [365] "Master_fultimo_cierre_lag2_lag1"
#  [366] "Master_fechaalta_lag2_lag1"
#  [367] "Master_mconsumototal_lag2_lag1"
#  [368] "Master_cconsumos_lag2_lag1"
#  [369] "Master_mpagominimo_lag2_lag1"
#  [370] "Visa_status_lag2_lag1"
#  [371] "Visa_mfinanciacion_limite_lag2_lag1"
#  [372] "Visa_Fvencimiento_lag2_lag1"
#  [373] "Visa_msaldototal_lag2_lag1"
#  [374] "Visa_mlimitecompra_lag2_lag1"
#  [375] "Visa_fultimo_cierre_lag2_lag1"
#  [376] "Visa_fechaalta_lag2_lag1"
#  [377] "Visa_mconsumototal_lag2_lag1"
#  [378] "Visa_cconsumos_lag2_lag1"
#  [379] "Visa_mpagominimo_lag2_lag1"
#  [380] "kmes_lag2_lag1"
#  [381] "mpayroll_sobre_edad_lag2_lag1"
#  [382] "internet_delta1_lag1"
#  [383] "internet_delta2_lag1"
#  [384] "cliente_edad_delta1_lag1"
#  [385] "cliente_edad_delta2_lag1"
#  [386] "cliente_antiguedad_delta1_lag1"
#  [387] "cliente_antiguedad_delta2_lag1"
#  [388] "mrentabilidad_delta1_lag1"
#  [389] "mrentabilidad_delta2_lag1"
#  [390] "mrentabilidad_annual_delta1_lag1"
#  [391] "mrentabilidad_annual_delta2_lag1"
#  [392] "mcomisiones_delta1_lag1"
#  [393] "mcomisiones_delta2_lag1"
#  [394] "mactivos_margen_delta1_lag1"
#  [395] "mactivos_margen_delta2_lag1"
#  [396] "mpasivos_margen_delta1_lag1"
#  [397] "mpasivos_margen_delta2_lag1"
#  [398] "cproductos_delta1_lag1"
#  [399] "cproductos_delta2_lag1"
#  [400] "mcuenta_corriente_delta1_lag1"
#  [401] "mcuenta_corriente_delta2_lag1"
#  [402] "mcaja_ahorro_delta1_lag1"
#  [403] "mcaja_ahorro_delta2_lag1"
#  [404] "cdescubierto_preacordado_delta1_lag1"
#  [405] "cdescubierto_preacordado_delta2_lag1"
#  [406] "mcuentas_saldo_delta1_lag1"
#  [407] "mcuentas_saldo_delta2_lag1"
#  [408] "ctarjeta_visa_delta1_lag1"
#  [409] "ctarjeta_visa_delta2_lag1"
#  [410] "ctarjeta_visa_transacciones_delta1_lag1"
#  [411] "ctarjeta_visa_transacciones_delta2_lag1"
#  [412] "mtarjeta_visa_consumo_delta1_lag1"
#  [413] "mtarjeta_visa_consumo_delta2_lag1"
#  [414] "ctarjeta_master_delta1_lag1"
#  [415] "ctarjeta_master_delta2_lag1"
#  [416] "ctarjeta_master_transacciones_delta1_lag1"
#  [417] "ctarjeta_master_transacciones_delta2_lag1"
#  [418] "mtarjeta_master_consumo_delta1_lag1"
#  [419] "mtarjeta_master_consumo_delta2_lag1"
#  [420] "cprestamos_personales_delta1_lag1"
#  [421] "cprestamos_personales_delta2_lag1"
#  [422] "mprestamos_personales_delta1_lag1"
#  [423] "mprestamos_personales_delta2_lag1"
#  [424] "cpayroll_trx_delta1_lag1"
#  [425] "cpayroll_trx_delta2_lag1"
#  [426] "mpayroll_delta1_lag1"
#  [427] "mpayroll_delta2_lag1"
#  [428] "mttarjeta_visa_debitos_automaticos_delta1_lag1"
#  [429] "mttarjeta_visa_debitos_automaticos_delta2_lag1"
#  [430] "ccomisiones_mantenimiento_delta1_lag1"
#  [431] "ccomisiones_mantenimiento_delta2_lag1"
#  [432] "mcomisiones_mantenimiento_delta1_lag1"
#  [433] "mcomisiones_mantenimiento_delta2_lag1"
#  [434] "ccomisiones_otras_delta1_lag1"
#  [435] "ccomisiones_otras_delta2_lag1"
#  [436] "mtransferencias_recibidas_delta1_lag1"
#  [437] "mtransferencias_recibidas_delta2_lag1"
#  [438] "ccallcenter_transacciones_delta1_lag1"
#  [439] "ccallcenter_transacciones_delta2_lag1"
#  [440] "thomebanking_delta1_lag1"
#  [441] "thomebanking_delta2_lag1"
#  [442] "chomebanking_transacciones_delta1_lag1"
#  [443] "chomebanking_transacciones_delta2_lag1"
#  [444] "ctrx_quarter_delta1_lag1"
#  [445] "ctrx_quarter_delta2_lag1"
#  [446] "Master_status_delta1_lag1"
#  [447] "Master_status_delta2_lag1"
#  [448] "Master_mfinanciacion_limite_delta1_lag1"
#  [449] "Master_mfinanciacion_limite_delta2_lag1"
#  [450] "Master_Fvencimiento_delta1_lag1"
#  [451] "Master_Fvencimiento_delta2_lag1"
#  [452] "Master_msaldototal_delta1_lag1"
#  [453] "Master_msaldototal_delta2_lag1"
#  [454] "Master_mlimitecompra_delta1_lag1"
#  [455] "Master_mlimitecompra_delta2_lag1"
#  [456] "Master_fultimo_cierre_delta1_lag1"
#  [457] "Master_fultimo_cierre_delta2_lag1"
#  [458] "Master_fechaalta_delta1_lag1"
#  [459] "Master_fechaalta_delta2_lag1"
#  [460] "Master_mconsumototal_delta1_lag1"
#  [461] "Master_mconsumototal_delta2_lag1"
#  [462] "Master_cconsumos_delta1_lag1"
#  [463] "Master_cconsumos_delta2_lag1"
#  [464] "Master_mpagominimo_delta1_lag1"
#  [465] "Master_mpagominimo_delta2_lag1"
#  [466] "Visa_status_delta1_lag1"
#  [467] "Visa_status_delta2_lag1"
#  [468] "Visa_mfinanciacion_limite_delta1_lag1"
#  [469] "Visa_mfinanciacion_limite_delta2_lag1"
#  [470] "Visa_Fvencimiento_delta1_lag1"
#  [471] "Visa_Fvencimiento_delta2_lag1"
#  [472] "Visa_msaldototal_delta1_lag1"
#  [473] "Visa_msaldototal_delta2_lag1"
#  [474] "Visa_mlimitecompra_delta1_lag1"
#  [475] "Visa_mlimitecompra_delta2_lag1"
#  [476] "Visa_fultimo_cierre_delta1_lag1"
#  [477] "Visa_fultimo_cierre_delta2_lag1"
#  [478] "Visa_fechaalta_delta1_lag1"
#  [479] "Visa_fechaalta_delta2_lag1"
#  [480] "Visa_mconsumototal_delta1_lag1"
#  [481] "Visa_mconsumototal_delta2_lag1"
#  [482] "Visa_cconsumos_delta1_lag1"
#  [483] "Visa_cconsumos_delta2_lag1"
#  [484] "Visa_mpagominimo_delta1_lag1"
#  [485] "Visa_mpagominimo_delta2_lag1"
#  [486] "kmes_delta1_lag1"
#  [487] "kmes_delta2_lag1"
#  [488] "mpayroll_sobre_edad_delta1_lag1"
#  [489] "mpayroll_sobre_edad_delta2_lag1"
#  [490] "internet_lag1_lag2"
#  [491] "cliente_edad_lag1_lag2"
#  [492] "cliente_antiguedad_lag1_lag2"
#  [493] "mrentabilidad_lag1_lag2"
#  [494] "mrentabilidad_annual_lag1_lag2"
#  [495] "mcomisiones_lag1_lag2"
#  [496] "mactivos_margen_lag1_lag2"
#  [497] "mpasivos_margen_lag1_lag2"
#  [498] "cproductos_lag1_lag2"
#  [499] "mcuenta_corriente_lag1_lag2"
#  [500] "mcaja_ahorro_lag1_lag2"
#  [501] "cdescubierto_preacordado_lag1_lag2"
#  [502] "mcuentas_saldo_lag1_lag2"
#  [503] "ctarjeta_visa_lag1_lag2"
#  [504] "ctarjeta_visa_transacciones_lag1_lag2"
#  [505] "mtarjeta_visa_consumo_lag1_lag2"
#  [506] "ctarjeta_master_lag1_lag2"
#  [507] "ctarjeta_master_transacciones_lag1_lag2"
#  [508] "mtarjeta_master_consumo_lag1_lag2"
#  [509] "cprestamos_personales_lag1_lag2"
#  [510] "mprestamos_personales_lag1_lag2"
#  [511] "cpayroll_trx_lag1_lag2"
#  [512] "mpayroll_lag1_lag2"
#  [513] "mttarjeta_visa_debitos_automaticos_lag1_lag2"
#  [514] "ccomisiones_mantenimiento_lag1_lag2"
#  [515] "mcomisiones_mantenimiento_lag1_lag2"
#  [516] "ccomisiones_otras_lag1_lag2"
#  [517] "mtransferencias_recibidas_lag1_lag2"
#  [518] "ccallcenter_transacciones_lag1_lag2"
#  [519] "thomebanking_lag1_lag2"
#  [520] "chomebanking_transacciones_lag1_lag2"
#  [521] "ctrx_quarter_lag1_lag2"
#  [522] "Master_status_lag1_lag2"
#  [523] "Master_mfinanciacion_limite_lag1_lag2"
#  [524] "Master_Fvencimiento_lag1_lag2"
#  [525] "Master_msaldototal_lag1_lag2"
#  [526] "Master_mlimitecompra_lag1_lag2"
#  [527] "Master_fultimo_cierre_lag1_lag2"
#  [528] "Master_fechaalta_lag1_lag2"
#  [529] "Master_mconsumototal_lag1_lag2"
#  [530] "Master_cconsumos_lag1_lag2"
#  [531] "Master_mpagominimo_lag1_lag2"
#  [532] "Visa_status_lag1_lag2"
#  [533] "Visa_mfinanciacion_limite_lag1_lag2"
#  [534] "Visa_Fvencimiento_lag1_lag2"
#  [535] "Visa_msaldototal_lag1_lag2"
#  [536] "Visa_mlimitecompra_lag1_lag2"
#  [537] "Visa_fultimo_cierre_lag1_lag2"
#  [538] "Visa_fechaalta_lag1_lag2"
#  [539] "Visa_mconsumototal_lag1_lag2"
#  [540] "Visa_cconsumos_lag1_lag2"
#  [541] "Visa_mpagominimo_lag1_lag2"
#  [542] "kmes_lag1_lag2"
#  [543] "mpayroll_sobre_edad_lag1_lag2"
#  [544] "internet_lag2_lag2"
#  [545] "cliente_edad_lag2_lag2"
#  [546] "cliente_antiguedad_lag2_lag2"
#  [547] "mrentabilidad_lag2_lag2"
#  [548] "mrentabilidad_annual_lag2_lag2"
#  [549] "mcomisiones_lag2_lag2"
#  [550] "mactivos_margen_lag2_lag2"
#  [551] "mpasivos_margen_lag2_lag2"
#  [552] "cproductos_lag2_lag2"
#  [553] "mcuenta_corriente_lag2_lag2"
#  [554] "mcaja_ahorro_lag2_lag2"
#  [555] "cdescubierto_preacordado_lag2_lag2"
#  [556] "mcuentas_saldo_lag2_lag2"
#  [557] "ctarjeta_visa_lag2_lag2"
#  [558] "ctarjeta_visa_transacciones_lag2_lag2"
#  [559] "mtarjeta_visa_consumo_lag2_lag2"
#  [560] "ctarjeta_master_lag2_lag2"
#  [561] "ctarjeta_master_transacciones_lag2_lag2"
#  [562] "mtarjeta_master_consumo_lag2_lag2"
#  [563] "cprestamos_personales_lag2_lag2"
#  [564] "mprestamos_personales_lag2_lag2"
#  [565] "cpayroll_trx_lag2_lag2"
#  [566] "mpayroll_lag2_lag2"
#  [567] "mttarjeta_visa_debitos_automaticos_lag2_lag2"
#  [568] "ccomisiones_mantenimiento_lag2_lag2"
#  [569] "mcomisiones_mantenimiento_lag2_lag2"
#  [570] "ccomisiones_otras_lag2_lag2"
#  [571] "mtransferencias_recibidas_lag2_lag2"
#  [572] "ccallcenter_transacciones_lag2_lag2"
#  [573] "thomebanking_lag2_lag2"
#  [574] "chomebanking_transacciones_lag2_lag2"
#  [575] "ctrx_quarter_lag2_lag2"
#  [576] "Master_status_lag2_lag2"
#  [577] "Master_mfinanciacion_limite_lag2_lag2"
#  [578] "Master_Fvencimiento_lag2_lag2"
#  [579] "Master_msaldototal_lag2_lag2"
#  [580] "Master_mlimitecompra_lag2_lag2"
#  [581] "Master_fultimo_cierre_lag2_lag2"
#  [582] "Master_fechaalta_lag2_lag2"
#  [583] "Master_mconsumototal_lag2_lag2"
#  [584] "Master_cconsumos_lag2_lag2"
#  [585] "Master_mpagominimo_lag2_lag2"
#  [586] "Visa_status_lag2_lag2"
#  [587] "Visa_mfinanciacion_limite_lag2_lag2"
#  [588] "Visa_Fvencimiento_lag2_lag2"
#  [589] "Visa_msaldototal_lag2_lag2"
#  [590] "Visa_mlimitecompra_lag2_lag2"
#  [591] "Visa_fultimo_cierre_lag2_lag2"
#  [592] "Visa_fechaalta_lag2_lag2"
#  [593] "Visa_mconsumototal_lag2_lag2"
#  [594] "Visa_cconsumos_lag2_lag2"
#  [595] "Visa_mpagominimo_lag2_lag2"
#  [596] "kmes_lag2_lag2"
#  [597] "mpayroll_sobre_edad_lag2_lag2"
#  [598] "internet_delta1_lag2"
#  [599] "internet_delta2_lag2"
#  [600] "cliente_edad_delta1_lag2"
#  [601] "cliente_edad_delta2_lag2"
#  [602] "cliente_antiguedad_delta1_lag2"
#  [603] "cliente_antiguedad_delta2_lag2"
#  [604] "mrentabilidad_delta1_lag2"
#  [605] "mrentabilidad_delta2_lag2"
#  [606] "mrentabilidad_annual_delta1_lag2"
#  [607] "mrentabilidad_annual_delta2_lag2"
#  [608] "mcomisiones_delta1_lag2"
#  [609] "mcomisiones_delta2_lag2"
#  [610] "mactivos_margen_delta1_lag2"
#  [611] "mactivos_margen_delta2_lag2"
#  [612] "mpasivos_margen_delta1_lag2"
#  [613] "mpasivos_margen_delta2_lag2"
#  [614] "cproductos_delta1_lag2"
#  [615] "cproductos_delta2_lag2"
#  [616] "mcuenta_corriente_delta1_lag2"
#  [617] "mcuenta_corriente_delta2_lag2"
#  [618] "mcaja_ahorro_delta1_lag2"
#  [619] "mcaja_ahorro_delta2_lag2"
#  [620] "cdescubierto_preacordado_delta1_lag2"
#  [621] "cdescubierto_preacordado_delta2_lag2"
#  [622] "mcuentas_saldo_delta1_lag2"
#  [623] "mcuentas_saldo_delta2_lag2"
#  [624] "ctarjeta_visa_delta1_lag2"
#  [625] "ctarjeta_visa_delta2_lag2"
#  [626] "ctarjeta_visa_transacciones_delta1_lag2"
#  [627] "ctarjeta_visa_transacciones_delta2_lag2"
#  [628] "mtarjeta_visa_consumo_delta1_lag2"
#  [629] "mtarjeta_visa_consumo_delta2_lag2"
#  [630] "ctarjeta_master_delta1_lag2"
#  [631] "ctarjeta_master_delta2_lag2"
#  [632] "ctarjeta_master_transacciones_delta1_lag2"
#  [633] "ctarjeta_master_transacciones_delta2_lag2"
#  [634] "mtarjeta_master_consumo_delta1_lag2"
#  [635] "mtarjeta_master_consumo_delta2_lag2"
#  [636] "cprestamos_personales_delta1_lag2"
#  [637] "cprestamos_personales_delta2_lag2"
#  [638] "mprestamos_personales_delta1_lag2"
#  [639] "mprestamos_personales_delta2_lag2"
#  [640] "cpayroll_trx_delta1_lag2"
#  [641] "cpayroll_trx_delta2_lag2"
#  [642] "mpayroll_delta1_lag2"
#  [643] "mpayroll_delta2_lag2"
#  [644] "mttarjeta_visa_debitos_automaticos_delta1_lag2"
#  [645] "mttarjeta_visa_debitos_automaticos_delta2_lag2"
#  [646] "ccomisiones_mantenimiento_delta1_lag2"
#  [647] "ccomisiones_mantenimiento_delta2_lag2"
#  [648] "mcomisiones_mantenimiento_delta1_lag2"
#  [649] "mcomisiones_mantenimiento_delta2_lag2"
#  [650] "ccomisiones_otras_delta1_lag2"
#  [651] "ccomisiones_otras_delta2_lag2"
#  [652] "mtransferencias_recibidas_delta1_lag2"
#  [653] "mtransferencias_recibidas_delta2_lag2"
#  [654] "ccallcenter_transacciones_delta1_lag2"
#  [655] "ccallcenter_transacciones_delta2_lag2"
#  [656] "thomebanking_delta1_lag2"
#  [657] "thomebanking_delta2_lag2"
#  [658] "chomebanking_transacciones_delta1_lag2"
#  [659] "chomebanking_transacciones_delta2_lag2"
#  [660] "ctrx_quarter_delta1_lag2"
#  [661] "ctrx_quarter_delta2_lag2"
#  [662] "Master_status_delta1_lag2"
#  [663] "Master_status_delta2_lag2"
#  [664] "Master_mfinanciacion_limite_delta1_lag2"
#  [665] "Master_mfinanciacion_limite_delta2_lag2"
#  [666] "Master_Fvencimiento_delta1_lag2"
#  [667] "Master_Fvencimiento_delta2_lag2"
#  [668] "Master_msaldototal_delta1_lag2"
#  [669] "Master_msaldototal_delta2_lag2"
#  [670] "Master_mlimitecompra_delta1_lag2"
#  [671] "Master_mlimitecompra_delta2_lag2"
#  [672] "Master_fultimo_cierre_delta1_lag2"
#  [673] "Master_fultimo_cierre_delta2_lag2"
#  [674] "Master_fechaalta_delta1_lag2"
#  [675] "Master_fechaalta_delta2_lag2"
#  [676] "Master_mconsumototal_delta1_lag2"
#  [677] "Master_mconsumototal_delta2_lag2"
#  [678] "Master_cconsumos_delta1_lag2"
#  [679] "Master_cconsumos_delta2_lag2"
#  [680] "Master_mpagominimo_delta1_lag2"
#  [681] "Master_mpagominimo_delta2_lag2"
#  [682] "Visa_status_delta1_lag2"
#  [683] "Visa_status_delta2_lag2"
#  [684] "Visa_mfinanciacion_limite_delta1_lag2"
#  [685] "Visa_mfinanciacion_limite_delta2_lag2"
#  [686] "Visa_Fvencimiento_delta1_lag2"
#  [687] "Visa_Fvencimiento_delta2_lag2"
#  [688] "Visa_msaldototal_delta1_lag2"
#  [689] "Visa_msaldototal_delta2_lag2"
#  [690] "Visa_mlimitecompra_delta1_lag2"
#  [691] "Visa_mlimitecompra_delta2_lag2"
#  [692] "Visa_fultimo_cierre_delta1_lag2"
#  [693] "Visa_fultimo_cierre_delta2_lag2"
#  [694] "Visa_fechaalta_delta1_lag2"
#  [695] "Visa_fechaalta_delta2_lag2"
#  [696] "Visa_mconsumototal_delta1_lag2"
#  [697] "Visa_mconsumototal_delta2_lag2"
#  [698] "Visa_cconsumos_delta1_lag2"
#  [699] "Visa_cconsumos_delta2_lag2"
#  [700] "Visa_mpagominimo_delta1_lag2"
#  [701] "Visa_mpagominimo_delta2_lag2"
#  [702] "kmes_delta1_lag2"
#  [703] "kmes_delta2_lag2"
#  [704] "mpayroll_sobre_edad_delta1_lag2"
#  [705] "mpayroll_sobre_edad_delta2_lag2"
#  [706] "internet_lag1_delta1"
#  [707] "internet_lag1_delta2"
#  [708] "cliente_edad_lag1_delta1"
#  [709] "cliente_edad_lag1_delta2"
#  [710] "cliente_antiguedad_lag1_delta1"
#  [711] "cliente_antiguedad_lag1_delta2"
#  [712] "mrentabilidad_lag1_delta1"
#  [713] "mrentabilidad_lag1_delta2"
#  [714] "mrentabilidad_annual_lag1_delta1"
#  [715] "mrentabilidad_annual_lag1_delta2"
#  [716] "mcomisiones_lag1_delta1"
#  [717] "mcomisiones_lag1_delta2"
#  [718] "mactivos_margen_lag1_delta1"
#  [719] "mactivos_margen_lag1_delta2"
#  [720] "mpasivos_margen_lag1_delta1"
#  [721] "mpasivos_margen_lag1_delta2"
#  [722] "cproductos_lag1_delta1"
#  [723] "cproductos_lag1_delta2"
#  [724] "mcuenta_corriente_lag1_delta1"
#  [725] "mcuenta_corriente_lag1_delta2"
#  [726] "mcaja_ahorro_lag1_delta1"
#  [727] "mcaja_ahorro_lag1_delta2"
#  [728] "cdescubierto_preacordado_lag1_delta1"
#  [729] "cdescubierto_preacordado_lag1_delta2"
#  [730] "mcuentas_saldo_lag1_delta1"
#  [731] "mcuentas_saldo_lag1_delta2"
#  [732] "ctarjeta_visa_lag1_delta1"
#  [733] "ctarjeta_visa_lag1_delta2"
#  [734] "ctarjeta_visa_transacciones_lag1_delta1"
#  [735] "ctarjeta_visa_transacciones_lag1_delta2"
#  [736] "mtarjeta_visa_consumo_lag1_delta1"
#  [737] "mtarjeta_visa_consumo_lag1_delta2"
#  [738] "ctarjeta_master_lag1_delta1"
#  [739] "ctarjeta_master_lag1_delta2"
#  [740] "ctarjeta_master_transacciones_lag1_delta1"
#  [741] "ctarjeta_master_transacciones_lag1_delta2"
#  [742] "mtarjeta_master_consumo_lag1_delta1"
#  [743] "mtarjeta_master_consumo_lag1_delta2"
#  [744] "cprestamos_personales_lag1_delta1"
#  [745] "cprestamos_personales_lag1_delta2"
#  [746] "mprestamos_personales_lag1_delta1"
#  [747] "mprestamos_personales_lag1_delta2"
#  [748] "cpayroll_trx_lag1_delta1"
#  [749] "cpayroll_trx_lag1_delta2"
#  [750] "mpayroll_lag1_delta1"
#  [751] "mpayroll_lag1_delta2"
#  [752] "mttarjeta_visa_debitos_automaticos_lag1_delta1"
#  [753] "mttarjeta_visa_debitos_automaticos_lag1_delta2"
#  [754] "ccomisiones_mantenimiento_lag1_delta1"
#  [755] "ccomisiones_mantenimiento_lag1_delta2"
#  [756] "mcomisiones_mantenimiento_lag1_delta1"
#  [757] "mcomisiones_mantenimiento_lag1_delta2"
#  [758] "ccomisiones_otras_lag1_delta1"
#  [759] "ccomisiones_otras_lag1_delta2"
#  [760] "mtransferencias_recibidas_lag1_delta1"
#  [761] "mtransferencias_recibidas_lag1_delta2"
#  [762] "ccallcenter_transacciones_lag1_delta1"
#  [763] "ccallcenter_transacciones_lag1_delta2"
#  [764] "thomebanking_lag1_delta1"
#  [765] "thomebanking_lag1_delta2"
#  [766] "chomebanking_transacciones_lag1_delta1"
#  [767] "chomebanking_transacciones_lag1_delta2"
#  [768] "ctrx_quarter_lag1_delta1"
#  [769] "ctrx_quarter_lag1_delta2"
#  [770] "Master_status_lag1_delta1"
#  [771] "Master_status_lag1_delta2"
#  [772] "Master_mfinanciacion_limite_lag1_delta1"
#  [773] "Master_mfinanciacion_limite_lag1_delta2"
#  [774] "Master_Fvencimiento_lag1_delta1"
#  [775] "Master_Fvencimiento_lag1_delta2"
#  [776] "Master_msaldototal_lag1_delta1"
#  [777] "Master_msaldototal_lag1_delta2"
#  [778] "Master_mlimitecompra_lag1_delta1"
#  [779] "Master_mlimitecompra_lag1_delta2"
#  [780] "Master_fultimo_cierre_lag1_delta1"
#  [781] "Master_fultimo_cierre_lag1_delta2"
#  [782] "Master_fechaalta_lag1_delta1"
#  [783] "Master_fechaalta_lag1_delta2"
#  [784] "Master_mconsumototal_lag1_delta1"
#  [785] "Master_mconsumototal_lag1_delta2"
#  [786] "Master_cconsumos_lag1_delta1"
#  [787] "Master_cconsumos_lag1_delta2"
#  [788] "Master_mpagominimo_lag1_delta1"
#  [789] "Master_mpagominimo_lag1_delta2"
#  [790] "Visa_status_lag1_delta1"
#  [791] "Visa_status_lag1_delta2"
#  [792] "Visa_mfinanciacion_limite_lag1_delta1"
#  [793] "Visa_mfinanciacion_limite_lag1_delta2"
#  [794] "Visa_Fvencimiento_lag1_delta1"
#  [795] "Visa_Fvencimiento_lag1_delta2"
#  [796] "Visa_msaldototal_lag1_delta1"
#  [797] "Visa_msaldototal_lag1_delta2"
#  [798] "Visa_mlimitecompra_lag1_delta1"
#  [799] "Visa_mlimitecompra_lag1_delta2"
#  [800] "Visa_fultimo_cierre_lag1_delta1"
#  [801] "Visa_fultimo_cierre_lag1_delta2"
#  [802] "Visa_fechaalta_lag1_delta1"
#  [803] "Visa_fechaalta_lag1_delta2"
#  [804] "Visa_mconsumototal_lag1_delta1"
#  [805] "Visa_mconsumototal_lag1_delta2"
#  [806] "Visa_cconsumos_lag1_delta1"
#  [807] "Visa_cconsumos_lag1_delta2"
#  [808] "Visa_mpagominimo_lag1_delta1"
#  [809] "Visa_mpagominimo_lag1_delta2"
#  [810] "kmes_lag1_delta1"
#  [811] "kmes_lag1_delta2"
#  [812] "mpayroll_sobre_edad_lag1_delta1"
#  [813] "mpayroll_sobre_edad_lag1_delta2"
#  [814] "internet_lag2_delta1"
#  [815] "internet_lag2_delta2"
#  [816] "cliente_edad_lag2_delta1"
#  [817] "cliente_edad_lag2_delta2"
#  [818] "cliente_antiguedad_lag2_delta1"
#  [819] "cliente_antiguedad_lag2_delta2"
#  [820] "mrentabilidad_lag2_delta1"
#  [821] "mrentabilidad_lag2_delta2"
#  [822] "mrentabilidad_annual_lag2_delta1"
#  [823] "mrentabilidad_annual_lag2_delta2"
#  [824] "mcomisiones_lag2_delta1"
#  [825] "mcomisiones_lag2_delta2"
#  [826] "mactivos_margen_lag2_delta1"
#  [827] "mactivos_margen_lag2_delta2"
# ...
#  [862] "ccomisiones_mantenimiento_lag2_delta1"
#  [863] "ccomisiones_mantenimiento_lag2_delta2"
#  [864] "mcomisiones_mantenimiento_lag2_delta1"
#  [865] "mcomisiones_mantenimiento_lag2_delta2"
#  [866] "ccomisiones_otras_lag2_delta1"
#  [867] "ccomisiones_otras_lag2_delta2"
#  [868] "mtransferencias_recibidas_lag2_delta1"
#  [869] "mtransferencias_recibidas_lag2_delta2"
#  [870] "ccallcenter_transacciones_lag2_delta1"
#  [871] "ccallcenter_transacciones_lag2_delta2"
#  [872] "thomebanking_lag2_delta1"
#  [873] "thomebanking_lag2_delta2"
#  [874] "chomebanking_transacciones_lag2_delta1"
#  [875] "chomebanking_transacciones_lag2_delta2"
#  [876] "ctrx_quarter_lag2_delta1"
#  [877] "ctrx_quarter_lag2_delta2"
#  [878] "Master_status_lag2_delta1"
#  [879] "Master_status_lag2_delta2"
#  [880] "Master_mfinanciacion_limite_lag2_delta1"
#  [881] "Master_mfinanciacion_limite_lag2_delta2"
#  [882] "Master_Fvencimiento_lag2_delta1"
#  [883] "Master_Fvencimiento_lag2_delta2"
#  [884] "Master_msaldototal_lag2_delta1"
#  [885] "Master_msaldototal_lag2_delta2"
#  [886] "Master_mlimitecompra_lag2_delta1"
#  [887] "Master_mlimitecompra_lag2_delta2"
#  [888] "Master_fultimo_cierre_lag2_delta1"
#  [889] "Master_fultimo_cierre_lag2_delta2"
#  [890] "Master_fechaalta_lag2_delta1"
#  [891] "Master_fechaalta_lag2_delta2"
#  [892] "Master_mconsumototal_lag2_delta1"
#  [893] "Master_mconsumototal_lag2_delta2"
#  [894] "Master_cconsumos_lag2_delta1"
#  [895] "Master_cconsumos_lag2_delta2"
#  [896] "Master_mpagominimo_lag2_delta1"
#  [897] "Master_mpagominimo_lag2_delta2"
#  [898] "Visa_status_lag2_delta1"
#  [899] "Visa_status_lag2_delta2"
#  [900] "Visa_mfinanciacion_limite_lag2_delta1"
#  [901] "Visa_mfinanciacion_limite_lag2_delta2"
#  [902] "Visa_Fvencimiento_lag2_delta1"
#  [903] "Visa_Fvencimiento_lag2_delta2"
#  [904] "Visa_msaldototal_lag2_delta1"
#  [905] "Visa_msaldototal_lag2_delta2"
#  [906] "Visa_mlimitecompra_lag2_delta1"
#  [907] "Visa_mlimitecompra_lag2_delta2"
#  [908] "Visa_fultimo_cierre_lag2_delta1"
#  [909] "Visa_fultimo_cierre_lag2_delta2"
#  [910] "Visa_fechaalta_lag2_delta1"
#  [911] "Visa_fechaalta_lag2_delta2"
#  [912] "Visa_mconsumototal_lag2_delta1"
#  [913] "Visa_mconsumototal_lag2_delta2"
#  [914] "Visa_cconsumos_lag2_delta1"
#  [915] "Visa_cconsumos_lag2_delta2"
#  [916] "Visa_mpagominimo_lag2_delta1"
#  [917] "Visa_mpagominimo_lag2_delta2"
#  [918] "kmes_lag2_delta1"
#  [919] "kmes_lag2_delta2"
#  [920] "mpayroll_sobre_edad_lag2_delta1"
#  [921] "mpayroll_sobre_edad_lag2_delta2"
#  [922] "internet_delta1_delta1"
#  [923] "internet_delta1_delta2"
#  [924] "internet_delta2_delta1"
#  [925] "internet_delta2_delta2"
#  [926] "cliente_edad_delta1_delta1"
#  [927] "cliente_edad_delta1_delta2"
#  [928] "cliente_edad_delta2_delta1"
#  [929] "cliente_edad_delta2_delta2"
#  [930] "cliente_antiguedad_delta1_delta1"
#  [931] "cliente_antiguedad_delta1_delta2"
#  [932] "cliente_antiguedad_delta2_delta1"
#  [933] "cliente_antiguedad_delta2_delta2"
#  [934] "mrentabilidad_delta1_delta1"
#  [935] "mrentabilidad_delta1_delta2"
#  [936] "mrentabilidad_delta2_delta1"
#  [937] "mrentabilidad_delta2_delta2"
#  [938] "mrentabilidad_annual_delta1_delta1"
#  [939] "mrentabilidad_annual_delta1_delta2"
#  [940] "mrentabilidad_annual_delta2_delta1"
#  [941] "mrentabilidad_annual_delta2_delta2"
#  [942] "mcomisiones_delta1_delta1"
#  [943] "mcomisiones_delta1_delta2"
#  [944] "mcomisiones_delta2_delta1"
#  [945] "mcomisiones_delta2_delta2"
#  [946] "mactivos_margen_delta1_delta1"
#  [947] "mactivos_margen_delta1_delta2"
#  [948] "mactivos_margen_delta2_delta1"
#  [949] "mactivos_margen_delta2_delta2"
#  [950] "mpasivos_margen_delta1_delta1"
#  [951] "mpasivos_margen_delta1_delta2"
#  [952] "mpasivos_margen_delta2_delta1"
#  [953] "mpasivos_margen_delta2_delta2"
#  [954] "cproductos_delta1_delta1"
#  [955] "cproductos_delta1_delta2"
#  [956] "cproductos_delta2_delta1"
#  [957] "cproductos_delta2_delta2"
#  [958] "mcuenta_corriente_delta1_delta1"
#  [959] "mcuenta_corriente_delta1_delta2"
#  [960] "mcuenta_corriente_delta2_delta1"
#  [961] "mcuenta_corriente_delta2_delta2"
#  [962] "mcaja_ahorro_delta1_delta1"
#  [963] "mcaja_ahorro_delta1_delta2"
#  [964] "mcaja_ahorro_delta2_delta1"
#  [965] "mcaja_ahorro_delta2_delta2"
#  [966] "cdescubierto_preacordado_delta1_delta1"
#  [967] "cdescubierto_preacordado_delta1_delta2"
#  [968] "cdescubierto_preacordado_delta2_delta1"
#  [969] "cdescubierto_preacordado_delta2_delta2"
#  [970] "mcuentas_saldo_delta1_delta1"
#  [971] "mcuentas_saldo_delta1_delta2"
#  [972] "mcuentas_saldo_delta2_delta1"
#  [973] "mcuentas_saldo_delta2_delta2"
#  [974] "ctarjeta_visa_delta1_delta1"
#  [975] "ctarjeta_visa_delta1_delta2"
#  [976] "ctarjeta_visa_delta2_delta1"
#  [977] "ctarjeta_visa_delta2_delta2"
#  [978] "ctarjeta_visa_transacciones_delta1_delta1"
#  [979] "ctarjeta_visa_transacciones_delta1_delta2"
#  [980] "ctarjeta_visa_transacciones_delta2_delta1"
#  [981] "ctarjeta_visa_transacciones_delta2_delta2"
#  [982] "mtarjeta_visa_consumo_delta1_delta1"
#  [983] "mtarjeta_visa_consumo_delta1_delta2"
#  [984] "mtarjeta_visa_consumo_delta2_delta1"
#  [985] "mtarjeta_visa_consumo_delta2_delta2"
#  [986] "ctarjeta_master_delta1_delta1"
#  [987] "ctarjeta_master_delta1_delta2"
#  [988] "ctarjeta_master_delta2_delta1"
#  [989] "ctarjeta_master_delta2_delta2"
#  [990] "ctarjeta_master_transacciones_delta1_delta1"
#  [991] "ctarjeta_master_transacciones_delta1_delta2"
#  [992] "ctarjeta_master_transacciones_delta2_delta1"
#  [993] "ctarjeta_master_transacciones_delta2_delta2"
#  [994] "mtarjeta_master_consumo_delta1_delta1"
#  [995] "mtarjeta_master_consumo_delta1_delta2"
#  [996] "mtarjeta_master_consumo_delta2_delta1"
#  [997] "mtarjeta_master_consumo_delta2_delta2"
#  [998] "cprestamos_personales_delta1_delta1"
#  [999] "cprestamos_personales_delta1_delta2"
# [1000] "cprestamos_personales_delta2_delta1"
# [1001] "cprestamos_personales_delta2_delta2"
# [1002] "mprestamos_personales_delta1_delta1"
# [1003] "mprestamos_personales_delta1_delta2"
# [1004] "mprestamos_personales_delta2_delta1"
# [1005] "mprestamos_personales_delta2_delta2"
# [1006] "cpayroll_trx_delta1_delta1"
# [1007] "cpayroll_trx_delta1_delta2"
# [1008] "cpayroll_trx_delta2_delta1"
# [1009] "cpayroll_trx_delta2_delta2"
# [1010] "mpayroll_delta1_delta1"
# [1011] "mpayroll_delta1_delta2"
# [1012] "mpayroll_delta2_delta1"
# [1013] "mpayroll_delta2_delta2"
# [1014] "mttarjeta_visa_debitos_automaticos_delta1_delta1"
# [1015] "mttarjeta_visa_debitos_automaticos_delta1_delta2"
# [1016] "mttarjeta_visa_debitos_automaticos_delta2_delta1"
# [1017] "mttarjeta_visa_debitos_automaticos_delta2_delta2"
# [1018] "ccomisiones_mantenimiento_delta1_delta1"
# [1019] "ccomisiones_mantenimiento_delta1_delta2"
# [1020] "ccomisiones_mantenimiento_delta2_delta1"
# [1021] "ccomisiones_mantenimiento_delta2_delta2"
# [1022] "mcomisiones_mantenimiento_delta1_delta1"
# [1023] "mcomisiones_mantenimiento_delta1_delta2"
# [1024] "mcomisiones_mantenimiento_delta2_delta1"
# [1025] "mcomisiones_mantenimiento_delta2_delta2"
# [1026] "ccomisiones_otras_delta1_delta1"
# [1027] "ccomisiones_otras_delta1_delta2"
# [1028] "ccomisiones_otras_delta2_delta1"
# [1029] "ccomisiones_otras_delta2_delta2"
# [1030] "mtransferencias_recibidas_delta1_delta1"
# [1031] "mtransferencias_recibidas_delta1_delta2"
# [1032] "mtransferencias_recibidas_delta2_delta1"
# [1033] "mtransferencias_recibidas_delta2_delta2"
# [1034] "ccallcenter_transacciones_delta1_delta1"
# [1035] "ccallcenter_transacciones_delta1_delta2"
# [1036] "ccallcenter_transacciones_delta2_delta1"
# [1037] "ccallcenter_transacciones_delta2_delta2"
# [1038] "thomebanking_delta1_delta1"
# [1039] "thomebanking_delta1_delta2"
# [1040] "thomebanking_delta2_delta1"
# [1041] "thomebanking_delta2_delta2"
# [1042] "chomebanking_transacciones_delta1_delta1"
# [1043] "chomebanking_transacciones_delta1_delta2"
# [1044] "chomebanking_transacciones_delta2_delta1"
# [1045] "chomebanking_transacciones_delta2_delta2"
# [1046] "ctrx_quarter_delta1_delta1"
# [1047] "ctrx_quarter_delta1_delta2"
# [1048] "ctrx_quarter_delta2_delta1"
# [1049] "ctrx_quarter_delta2_delta2"
# [1050] "Master_status_delta1_delta1"
# [1051] "Master_status_delta1_delta2"
# [1052] "Master_status_delta2_delta1"
# [1053] "Master_status_delta2_delta2"
# [1054] "Master_mfinanciacion_limite_delta1_delta1"
# [1055] "Master_mfinanciacion_limite_delta1_delta2"
# [1056] "Master_mfinanciacion_limite_delta2_delta1"
# [1057] "Master_mfinanciacion_limite_delta2_delta2"
# [1058] "Master_Fvencimiento_delta1_delta1"
# [1059] "Master_Fvencimiento_delta1_delta2"
# [1060] "Master_Fvencimiento_delta2_delta1"
# [1061] "Master_Fvencimiento_delta2_delta2"
# [1062] "Master_msaldototal_delta1_delta1"
# [1063] "Master_msaldototal_delta1_delta2"
# [1064] "Master_msaldototal_delta2_delta1"
# [1065] "Master_msaldototal_delta2_delta2"
# [1066] "Master_mlimitecompra_delta1_delta1"
# [1067] "Master_mlimitecompra_delta1_delta2"
# [1068] "Master_mlimitecompra_delta2_delta1"
# [1069] "Master_mlimitecompra_delta2_delta2"
# [1070] "Master_fultimo_cierre_delta1_delta1"
# [1071] "Master_fultimo_cierre_delta1_delta2"
# [1072] "Master_fultimo_cierre_delta2_delta1"
# [1073] "Master_fultimo_cierre_delta2_delta2"
# [1074] "Master_fechaalta_delta1_delta1"
# [1075] "Master_fechaalta_delta1_delta2"
# [1076] "Master_fechaalta_delta2_delta1"
# [1077] "Master_fechaalta_delta2_delta2"
# [1078] "Master_mconsumototal_delta1_delta1"
# [1079] "Master_mconsumototal_delta1_delta2"
# [1080] "Master_mconsumototal_delta2_delta1"
# [1081] "Master_mconsumototal_delta2_delta2"
# [1082] "Master_cconsumos_delta1_delta1"
# [1083] "Master_cconsumos_delta1_delta2"
# [1084] "Master_cconsumos_delta2_delta1"
# [1085] "Master_cconsumos_delta2_delta2"
# [1086] "Master_mpagominimo_delta1_delta1"
# [1087] "Master_mpagominimo_delta1_delta2"
# [1088] "Master_mpagominimo_delta2_delta1"
# [1089] "Master_mpagominimo_delta2_delta2"
# [1090] "Visa_status_delta1_delta1"
# [1091] "Visa_status_delta1_delta2"
# [1092] "Visa_status_delta2_delta1"
# [1093] "Visa_status_delta2_delta2"
# [1094] "Visa_mfinanciacion_limite_delta1_delta1"
# [1095] "Visa_mfinanciacion_limite_delta1_delta2"
# [1096] "Visa_mfinanciacion_limite_delta2_delta1"
# [1097] "Visa_mfinanciacion_limite_delta2_delta2"
# [1098] "Visa_Fvencimiento_delta1_delta1"
# [1099] "Visa_Fvencimiento_delta1_delta2"
# [1100] "Visa_Fvencimiento_delta2_delta1"
# [1101] "Visa_Fvencimiento_delta2_delta2"
# [1102] "Visa_msaldototal_delta1_delta1"
# [1103] "Visa_msaldototal_delta1_delta2"
# [1104] "Visa_msaldototal_delta2_delta1"
# [1105] "Visa_msaldototal_delta2_delta2"
# [1106] "Visa_mlimitecompra_delta1_delta1"
# [1107] "Visa_mlimitecompra_delta1_delta2"
# [1108] "Visa_mlimitecompra_delta2_delta1"
# [1109] "Visa_mlimitecompra_delta2_delta2"
# [1110] "Visa_fultimo_cierre_delta1_delta1"
# [1111] "Visa_fultimo_cierre_delta1_delta2"
# [1112] "Visa_fultimo_cierre_delta2_delta1"
# [1113] "Visa_fultimo_cierre_delta2_delta2"
# [1114] "Visa_fechaalta_delta1_delta1"
# [1115] "Visa_fechaalta_delta1_delta2"
# [1116] "Visa_fechaalta_delta2_delta1"
# [1117] "Visa_fechaalta_delta2_delta2"
# [1118] "Visa_mconsumototal_delta1_delta1"
# [1119] "Visa_mconsumototal_delta1_delta2"
# [1120] "Visa_mconsumototal_delta2_delta1"
# [1121] "Visa_mconsumototal_delta2_delta2"
# [1122] "Visa_cconsumos_delta1_delta1"
# [1123] "Visa_cconsumos_delta1_delta2"
# [1124] "Visa_cconsumos_delta2_delta1"
# [1125] "Visa_cconsumos_delta2_delta2"
# [1126] "Visa_mpagominimo_delta1_delta1"
# [1127] "Visa_mpagominimo_delta1_delta2"
# [1128] "Visa_mpagominimo_delta2_delta1"
# [1129] "Visa_mpagominimo_delta2_delta2"
# [1130] "kmes_delta1_delta1"
# [1131] "kmes_delta1_delta2"
# [1132] "kmes_delta2_delta1"
# [1133] "kmes_delta2_delta2"
# [1134] "mpayroll_sobre_edad_delta1_delta1"
# [1135] "mpayroll_sobre_edad_delta1_delta2"
# [1136] "mpayroll_sobre_edad_delta2_delta1"
# [1137] "mpayroll_sobre_edad_delta2_delta2"

# %% [markdown]
# #### 7.3.1.6  FEhist Reduccion dimensionalidad con canaritos
#
# Esta etapa solo se mostrará a la *modalidad Anlista Sr* por algun canal secreto de forma de no confundir a los *Analista Jr*  nni distraer con detalles operativos a la estratégica *Modalidad Gerencial*

# %%
# No se implementa la reduccion de la dimensionalidad con canaritos

# %% [markdown]
# ### 7.3.2 Modelado

# %% [markdown]
# #### 7.3.2.1 Training Strategy
#
# Esta etapa de Workflow de  Training Strategy esta pensada para la *Modalidad Gerencial* que posee el dataset de [202005, 202109]
# <br> Si usted es un Analista, posee el periodo de [201901, 202109] y deberá experimentar en que meses le conviene experimentar
#
# <br> A la *Modalidad Gerencial* no se le complicada la vida con el undersampling de los continua, por eso PARAM$trainingstrategy$training_pct <- 1.0
# <br> Sin embargo, si usted es  *Analista SR* posee un dataset 50 veces ( filas x columnas) más grande que la *Modalidad Gerencial*  y por un tema de velocidad y experimentación más rápida puede llegar a necesitar activar el undersampling de la clase mayoritaria, a pesar de estar corriendo en Google Cloud.

# %% [markdown]
# Se hace una estrategia de entrenamiento muy sencilla, tomando todos los meses posibles, SIN eliminar nada x pandemia ni por ningun otro motivo
#
# * future = 202109  obviamente completo
#
# * final_train =  [ 202005, 202107 ]  con un undersampling de los CONTINUA del 2% por un tema de velocidad
#
# * training
#    * testing = NO HAY
#    * validation =  202107   completo, sin undersampling
#    * training = [ 202005, 202106 ]  donde se consideran el 100% de los CONTINUA

# %%
PARAM$trainingstrategy$validate <- c(202107)

PARAM$trainingstrategy$training <- c(
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

PARAM$trainingstrategy$training_pct <- 1.0


PARAM$trainingstrategy$positivos <- c( "BAJA+1", "BAJA+2")

# %%
# seteo la clase01   1={BAJA+1, BAJA+2}   0={CONTINUA}
dataset[, clase01 := ifelse( clase_ternaria %in% PARAM$trainingstrategy$positivos, 1, 0 )]

# %%
# los campos en los que se entrena
campos_buenos <- copy( setdiff(
    colnames(dataset), c("clase_ternaria","clase01","azar"))
)

# %%
# preparo para que se puede hacer undersampling de los CONTINUA
#  solamente por un tema de VELOCIDAD
set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset[, azar:=runif(nrow(dataset))]

# undersampling de los CONTINUA
dataset[, fold_train :=  foto_mes %in%  PARAM$trainingstrategy$training &
    (clase_ternaria %in% c("BAJA+1", "BAJA+2") |
     azar < PARAM$trainingstrategy$training_pct ) ]


if( !require("lightgbm")) install.packages("lightgbm")
require("lightgbm")

dtrain <- lgb.Dataset(
  data= data.matrix(dataset[fold_train == TRUE, campos_buenos, with = FALSE]),
  label= dataset[fold_train == TRUE, clase01],
  free_raw_data= TRUE
)
# Out:
# Loading required package: lightgbm

# %%
# datos de validation
dvalidate <- lgb.Dataset(
  data= data.matrix(dataset[foto_mes %in% PARAM$trainingstrategy$validate, campos_buenos, with = FALSE]),
  label= dataset[foto_mes %in% PARAM$trainingstrategy$validate, clase01],
  free_raw_data= TRUE
)

nrow(dvalidate)
# Out:
# [1] 33053

# %% [markdown]
# ####  7.3.2.2. Hyperparameter Tuning

# %% [markdown]
# * Clase binaria que se optimiza :  positivos = [ BAJA+1, BAJA+2 ]

# %% [markdown]
# * Metrica que se optimiza **AUC** Area Under Curve de la  ROC Curve
#
# es muy importante notar que intencionalmente  **NO** se está optimizando la funcion de ganancia del problema

# %% [markdown]
# * Cantidad de iteraciones inteligentes de la Optimizacion Bayesiana = **10**

# %% [markdown]
# * Parametros no default, fijos de LightGBM que no se optimizan
#   * max_bin = 31 , Alienigenas Ancestrales contruyeron las pirámides y dejaron a la humanidad en un jeroglifico  *max_bin=31*
#   * feature_fraction = 0.5  para poner algo que generalmente no falla
#   * learning_rate = 0.03  para que aprenda lento

# %% [markdown]
# * Parametros que se optimizan en la Bayesian Optimization
#   * num_leaves  [8, 256]
#   * min_data_in_leaf  [8, 8192]

# %%
# paquetes necesarios para la Bayesian Optimization
if(!require("DiceKriging")) install.packages("DiceKriging")
require("DiceKriging")

if(!require("mlrMBO")) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# Definición de la Bayesian Optimization
# <br> Si se desea optimizar un hiperparámetro que esta como fijo, debe QUITARSE de param_fijos y agregarse a PARAM$hipeparametertuning$hs

# %%
# valor ridiculamente bajo para que corra rapido en el aula y no molestar a la *Modalidad Gerencial*
PARAM$hipeparametertuning$num_iterations <- 30


# parametros fijos del LightGBM
PARAM$lgbm$param_fijos <- list(
  objective= "binary",
  metric= "auc",
  first_metric_only= TRUE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  verbosity= -100,
  force_row_wise= TRUE, # para evitar warning
  seed= PARAM$semilla_primigenia,
  max_bin= 31,
  learning_rate= 0.027,
  feature_fraction= 0.8,
  num_iterations= 2083,  # valor grande, lo limita early_stopping_rounds
  early_stopping_rounds= 400
)

PARAM$hipeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_leaves", lower = 2L, upper = 256L),
  makeIntegerParam("min_data_in_leaf", lower = 2L, upper = 8192L)
)

# %% [markdown]
# Función "señora caja negra"  que es llamada para verificar la realidad por la Bayesian Optimization

# %%
# En  x llegan los parmaetros de la bayesiana
#  devuelve la AUC en validate del modelo entrenado
#  en el parametro x llegan los hiperparámetros que se estan optimizando

EstimarGanancia_AUC_lightgbm <- function(x) {

  message(format(Sys.time(), "%a %b %d %X %Y"))

  # uno la lista de hiperparametros : fijos + variables
  param_completo <- c(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelo_train <- lgb.train(
    data= dtrain,
    valids= list(valid = dvalidate),
    eval= "auc",
    param= param_completo,
    verbose= -100
  )

  # recupero la AUC en validation
  AUC <- modelo_train$record_evals$valid$auc$eval[[modelo_train$best_iter]]

  # esta es la forma de devolver un parametro extra
  attr(AUC, "extras") <- list("num_iterations"= modelo_train$best_iter)

  # hago espacio en la memoria
  rm(modelo_train)
  gc(full= TRUE, verbose= FALSE)

  return(AUC)
}

# %% [markdown]
# seteo de la Bayesian Optimization (complejo)
# <br> copiado y pegado de la documentación de la librería

# %%
configureMlr(show.learner.output = FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo
obj.fun <- makeSingleObjectiveFunction(
    fn= EstimarGanancia_AUC_lightgbm, # la funcion que voy a maximizar
    minimize= FALSE, # estoy Maximizando AUC
    noisy= FALSE,
    par.set= PARAM$hipeparametertuning$hs,
    has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
    save.on.disk.at.time= 600,
    save.file.path= "HT.RDATA"
)

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
    ctrl,
    iters= PARAM$hipeparametertuning$num_iterations  # ✅ correcto
)


# defino el método estandar para la creacion de los puntos iniciales
#   los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# mas configuraciones
surr.km <- makeLearner(
    "regr.km",
    predict.type= "se",
    covtype= "matern3_2",
    control= list(trace = TRUE)
)

# %% [markdown]
# Corrida de la Bayesian Optimization,  aqui se hace el trabajo pesado
# <br> por favor no se asuste con los warnings que pudieran aparecer
#
# Si corrío a medias y llegó a las iteraciones inteligentes, en el archivo binario HT.RDATA quedó lo ya procesado y es utilizado para retomar la corrida desde lo último que llegó a grabar.

# %%
# Establecer número de iteraciones deseadas
PARAM$hipeparametertuning$num_iterations <- 30  # cambiá este valor si querés más o menos

# Definir objeto de control (con el nuevo número de iteraciones)
ctrl <- makeMBOControl(
  save.on.disk.at.time = 600,
  save.file.path = "HT.RDATA"
)
ctrl <- setMBOControlTermination(ctrl, iters = PARAM$hipeparametertuning$num_iterations)
ctrl <- setMBOControlInfill(ctrl, crit = makeMBOInfillCritEI())

# Definir modelo sustituto (surrogate)
surr.km <- makeLearner(
  "regr.km",
  predict.type = "se",
  covtype = "matern3_2",
  control = list(trace = TRUE)
)

# Iniciar o continuar optimización bayesiana
if (!file.exists("HT.RDATA")) {
  message(">> Iniciando optimización desde cero...")
  bayesiana_salida <- mbo(obj.fun, learner = surr.km, control = ctrl)
} else {
  message(">> Retomando optimización desde archivo guardado...")
  bayesiana_salida <- mboContinue("HT.RDATA")
}

# Ver mejores parámetros encontrados
print(bayesiana_salida$x)
print(bayesiana_salida$y)
# Out:
# >> Retomando optimización desde archivo guardado...
#
# Warning message in mboContinue("HT.RDATA"):
# “Tuning ended with term.iter. No need to continue. Simply returning stored result.”
# $num_leaves
# [1] 256
#
# $min_data_in_leaf
# [1] 152
#
# [1] 0.9387164

# %% [markdown]
# la bayesian optimization ha corrido, extraigo los mejores hiperparametros

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y, -num_iterations)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file="BO_log.txt",
  sep="\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  list(num_leaves, min_data_in_leaf, num_iterations)
]

print(PARAM$out$lgbm$mejores_hiperparametros)
# Out:
#    num_leaves min_data_in_leaf num_iterations
#         <int>            <int>          <int>
# 1:        256              152            348

# %% [markdown]
# ### 7.3.3 Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
PARAM$trainingstrategy$final_train <- c( 202107,
  202106, 202105, 202104, 202103, 202102, 202101,
  202012, 202011, 202010, 202009, 202008, 202007,
  202006, 202005
)

dataset[, fold_final_train := foto_mes %in% PARAM$trainingstrategy$final_train ]

# creo el dfinal_train en formato  LightGBM
dfinal_train <- lgb.Dataset(
  data= data.matrix(dataset[fold_final_train == TRUE, campos_buenos, with= FALSE]),
  label= dataset[fold_final_train == TRUE, clase01],
  free_raw_data= TRUE
)

nrow( dfinal_train) # verifico el tamaño
# Out:
# [1] 480279

# %% [markdown]
# #### Final Training Hyperparameters

# %%
# uno los parametros fijos y los mejores encontrados de los variables
fijos <- copy(PARAM$lgbm$param_fijos)

# quito lo que optimice en la Bayesian Optimization
fijos$num_iterations <- NULL
fijos$early_stopping_rounds <- NULL

# agrego a los hiperparametros fijos los que encontre con la Bayesian Optimization
param_final <- c(fijos, PARAM$out$lgbm$mejores_hiperparametros)

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
final_model <- lgb.train(
  data= dfinal_train,
  param= param_final,
  verbose= -100
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(final_model, "modelo.txt")

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(final_model))
archivo_importancia <- "impo.txt"

fwrite( tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
PARAM$trainingstrategy$future <- c(202109)

dfuture <- dataset[ foto_mes %in% PARAM$trainingstrategy$future ]

# %%
# aplico final_model   a dfuture

prediccion <- predict(
  final_model,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion]

# grabo las probabilidad del modelo
#  me va a ser util para hacer Ensembles de modelos
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %% [markdown]
# Genero las salidas y hago los submits a Kaggle
# <br>El notebook esta preparado para la Modalidad Gerencial, los analistas deben hacer cambios.
# <br> Los analistas deben cambiar **competencia** a SU competencia  "labo-i-2025-rosario-analista-jr"   o  la original "labo-i-2025-rosario"  para los Senior
# <br> Los cortes  dependen de la cantidad de registros, multiplicar por 2 para los Analistas Jr y por 10 para los Analista Sr
#
# Los Analista Sr luego de meditar cuidadosamente reducirán la cantidad de cortes

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

PARAM$kaggle$competencia <- "labo-i-2025-rosario-analista-jr"
PARAM$kaggle$cortes <- seq(800, 1300, by = 50)

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
}

# %%
# grabo los parametros
if( !require("yaml")) install.packages("yaml")
require("yaml")

write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
